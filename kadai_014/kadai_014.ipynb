# %%
price1 = 100
price2 = 200

def total():
    tax = 1.1
    return price1 + price2

print (total() * tax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3452148127.py in <cell line: 0>()
#       6     return price1 + price2
#       7
# ----> 8 print (total() * tax)
#
# NameError: name 'tax' is not defined

# %%
#課題再提出
price1 = 100
price2 = 200
tax = 1.1

def total():

    return price1 + price2

total()
print (total() * tax)
# Out:
# 330.0

# %%
#失敗
def total(total):
    tax = 1.1
    return (price1 + price2) * tax

print (total(100 + 200) )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2578555624.py in <cell line: 0>()
#       3     return (price1 + price2) * tax
#       4
# ----> 5 print (total(100 + 200) )
#
# TypeError: total() takes 0 positional arguments but 1 was given

# %%
#課題回答
def total(price1, price2):

    tax = 1.1
    return (price1 + price2) * tax

print(total(100, 200))

#total(100, 200)で関数しか呼び出してないのに、(price1 + price2) * taxの結果は出るのか？
#→関数を呼び出すと、その中の処理（関数本体）が実行されるから (price1 + price2) * tax の結果が出る
# Out:
# 330.0

# %%
#練習
def total(price1,price2,tax):

    totals = (price1 + price2) * tax
    print (f"{totals}円")

total(100,200,1.1)
# Out:
# 330.0円
