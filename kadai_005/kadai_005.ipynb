# %%
trapezoid_top = 10
trapezoid_bottom = 20
trapezoid_height =5

print(f"台形の面積は{(trapezoid_top + trapezoid_bottom) * trapezoid_height / 2} ㎠です。")
# Out:
# 台形の面積は75.0 ㎠です。

# %%
trapezoid_top = 10
trapezoid_bottom = 20
trapezoid_height =5

trapezoid = (trapezoid_top + trapezoid_bottom) * trapezoid_height / 2

print(f"台形の面積は{trapezoid}㎠です。")
# Out:
# 台形の面積は75.0㎠です。
